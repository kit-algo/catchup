# %%
import numpy as np
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline

import pandas as pd

import json
import glob
import os

# %%
base_path = os.environ['TDCCH_EXP_OUTPUT_DIR']
paths = glob.glob(base_path + "/query_stats_no_astar_all_graphs/*.json")
data = [json.load(open(path)) for path in paths]

# %%
query_running_times = pd.DataFrame.from_records([{ 
    'graph': run['args'][1],
    **algo } 
    for run in data for algo in run["algo_runs"] if algo['algo'] == "Floating TDCCH Query"])

# %%
query_running_times.groupby('graph')[['running_time_ms', 'unpacking_running_time_ms']].mean()
# Out:
#                                                     running_time_ms  \
# graph
# /algoDaten/graphs/cleaned_td_road_data/ber/day/di/         0.905107
# /algoDaten/graphs/cleaned_td_road_data/ber/day/do/         0.804337
# /algoDaten/graphs/cleaned_td_road_data/ber/day/fr/         0.646205
# /algoDaten/graphs/cleaned_td_road_data/ber/day/mi/         0.673977
# /algoDaten/graphs/cleaned_td_road_data/ber/day/mo/         0.650946
# /algoDaten/graphs/cleaned_td_road_data/ber/day/sa/         0.321086
# /algoDaten/graphs/cleaned_td_road_data/ber/day/so/         0.284321
# /algoDaten/graphs/cleaned_td_road_data/de/day/d...         1.646175
# /algoDaten/graphs/cleaned_td_road_data/de/day/fr/          1.161402
# /algoDaten/graphs/cleaned_td_road_data/de/day/mo/          1.384483
# /algoDaten/graphs/cleaned_td_road_data/de/day/sa/          0.280337
# /algoDaten/graphs/cleaned_td_road_data/de/day/so/          0.209388
# /algoDaten/graphs/cleaned_td_road_data/eur/day/c1/         6.455726
# /algoDaten/graphs/cleaned_td_road_data/eur/day/c2/        16.906095
# /algoDaten/graphs/cleaned_td_road_data/eur/day/c3/        37.838422
# /algoDaten/graphs/cleaned_td_road_data/ptv16-de...         3.452556
# /algoDaten/graphs/cleaned_td_road_data/ptv17-de...        12.689306
# /algoDaten/graphs/cleaned_td_road_data/ptv17-de...         5.204244
# /algoDaten/graphs/cleaned_td_road_data/ptv17-eu...        25.420902
# /algoDaten/graphs/cleaned_td_road_data/ptv17-eu...        11.818999
# /algoDaten/graphs/cleaned_td_road_data/ptv17-lu...         0.238646
# /algoDaten/graphs/cleaned_td_road_data/ptv17-lu...         0.374413
#
#                                                     unpacking_running_time_ms
# graph
# /algoDaten/graphs/cleaned_td_road_data/ber/day/di/                   0.068415
# /algoDaten/graphs/cleaned_td_road_data/ber/day/do/                   0.061048
# /algoDaten/graphs/cleaned_td_road_data/ber/day/fr/                   0.052915
# /algoDaten/graphs/cleaned_td_road_data/ber/day/mi/                   0.054139
# /algoDaten/graphs/cleaned_td_road_data/ber/day/mo/                   0.053523
# /algoDaten/graphs/cleaned_td_road_data/ber/day/sa/                   0.046789
# /algoDaten/graphs/cleaned_td_road_data/ber/day/so/                   0.045943
# /algoDaten/graphs/cleaned_td_road_data/de/day/d...                   0.185708
# /algoDaten/graphs/cleaned_td_road_data/de/day/fr/                    0.177313
# /algoDaten/graphs/cleaned_td_road_data/de/day/mo/                    0.182636
# /algoDaten/graphs/cleaned_td_road_data/de/day/sa/                    0.136484
# /algoDaten/graphs/cleaned_td_road_data/de/day/so/                    0.131918
# /algoDaten/graphs/cleaned_td_road_data/eur/day/c1/                   0.387356
# /algoDaten/graphs/cleaned_td_road_data/eur/day/c2/                   0.407857
# /algoDaten/graphs/cleaned_td_road_data/eur/day/c3/                   0.517938
# /algoDaten/graphs/cleaned_td_road_data/ptv16-de...                   0.278692
# /algoDaten/graphs/cleaned_td_road_data/ptv17-de...                   0.545896
# /algoDaten/graphs/cleaned_td_road_data/ptv17-de...                   0.341584
# /algoDaten/graphs/cleaned_td_road_data/ptv17-eu...                   0.994758
# /algoDaten/graphs/cleaned_td_road_data/ptv17-eu...                   0.716196
# /algoDaten/graphs/cleaned_td_road_data/ptv17-lu...                   0.023057
# /algoDaten/graphs/cleaned_td_road_data/ptv17-lu...                   0.024868
