df = pd.DataFrame.from_records([{ "dt": dt, "label": "{:02d}:{:02d}".format(int(dt) // 3600, int(dt) // 60), "tt": tt } for (dt, tt) in data[::2]])
g = sns.relplot(data=df, x="dt", y="tt", kind="line", aspect=16/6, height=2)
g.set(xlabel='Entry time', ylabel='Travel time [s]', xlim=(0, 86400), xticks=[0, 21600, 43200, 64800, 86400], yticks=[14, 16, 18, 20])
g.set_xticklabels(['00:00', '06:00', '12:00', '18:00', '24:00'])
plt.tight_layout()
g.savefig('../../paper/fig/ttf.pdf')

# %%
sns.set_style("white")
df = pd.DataFrame.from_records([{ "dt": dt, "label": "{:02d}:{:02d}".format(int(dt) // 3600, int(dt) // 60), "tt": 200 * 3.6 / tt } for (dt, tt) in data[::2]])
g = sns.relplot(data=df, x="dt", y="tt", kind="line", aspect=4/3, height=2.9)
g.set(xlabel='Entry time', ylabel='Speed [km/s]', xlim=(0, 86400), xticks=[0, 21600, 43200, 64800, 86400])
g.set_xticklabels(['00:00', '06:00', '12:00', '18:00', '24:00'])
plt.tight_layout()
g.savefig('../../paper/fig/sf.pdf')

# %%
plt.figure(figsize=(12/3, 2.9))
g = sns.distplot(np.random.lognormal(3., .4, size=10000) + 20)
g.set(ylabel='Density', xlabel='Speed [km/s]')
plt.tight_layout()
plt.savefig('../../paper/fig/lognormal_square.pdf')

# %%
plt.figure(figsize=(32/6, 2))
g = sns.distplot(np.random.lognormal(3., .4, size=10000) + 20)
g.set(ylabel='Density', xlabel='Speed [km/s]')
plt.tight_layout()
plt.savefig('../../paper/fig/lognormal.pdf')

# %%
sns.set_style("white")
df = pd.DataFrame.from_records([{ "dt": dt, "tt": tt } for (dt, tt) in data[::2]])
g = sns.relplot(data=df, x="dt", y="tt", kind="line", aspect=16/9, height=3, linewidth=15)
g.set(xlabel='', ylabel='')
g.set_xticklabels([])
g.set_yticklabels([])
plt.tight_layout()
g.savefig('../../paper/fig/ttf_stripped.pdf')

# %%
sns.set_style("white")
df = pd.DataFrame.from_records([{ "dt": dt, "tt": tt } for (dt, tt) in [(0,2), (6,2.5), (9, 4), (12,3), (16,3.5), (17,4), (19,2), (24,2)]])
g = sns.relplot(data=df, x="dt", y="tt", kind="line", aspect=16/9, height=3, linewidth=15, color=sns.color_palette()[1])
g.set(xlabel='', ylabel='')
g.set_xticklabels([])
g.set_yticklabels([])
plt.tight_layout()
g.savefig('../../paper/fig/ttf2_stripped.pdf')

# %%
sns.set_style("white")
df = pd.DataFrame.from_records([{ "dt": dt, "tt": tt } for (dt, tt) in [(0,2), (6,2), (9, 4), (12,3), (16,3.5), (17,3), (22,2), (24,2)]])
g = sns.relplot(data=df, x="dt", y="tt", kind="line", aspect=16/9, height=3, linewidth=15, color=sns.color_palette()[2])
g.set(xlabel='', ylabel='')
g.set_xticklabels([])
g.set_yticklabels([])
plt.tight_layout()
g.savefig('../../paper/fig/ttf3_stripped.pdf')

# %%
sns.set_style("white")
df = pd.DataFrame.from_records([{ "dt": dt, "tt": tt } for (dt, tt) in [(0,2), (6,2.5), (9, 3), (12,3), (16,3.2), (17,3), (22,2), (24,2)]])
g = sns.relplot(data=df, x="dt", y="tt", kind="line", aspect=16/9, height=3, linewidth=15, color=sns.color_palette()[3])
g.set(xlabel='', ylabel='')
g.set_xticklabels([])
g.set_yticklabels([])
plt.tight_layout()
g.savefig('../../paper/fig/ttf4_stripped.pdf')

# %%
sns.set_style("white")
df = pd.DataFrame.from_records([{ "dt": dt, "tt": tt } for (dt, tt) in [(0,2),(24,2)]])
g = sns.relplot(data=df, x="dt", y="tt", kind="line", aspect=16/9, height=3, linewidth=15, color=sns.color_palette()[4])
g.set(xlabel='', ylabel='')
g.set_xticklabels([])
g.set_yticklabels([])
plt.tight_layout()
g.savefig('../../paper/fig/ttf5_stripped.pdf')

# %%
sns.set_style("white")
records = [{ "dt": dt, "tt": tt, 'foo':'f' } for (dt, tt) in [(6,10), (6.5, 10), (7.5, 9), (8, 9), (8.5, 10), (8.75, 12), (9, 11), (9.75, 10), (10,9), (10.5,8.5), (12,8), (12.5,8), (13.5,7), (14,7), (14.4, 7.5), (15,7.5), (16,9), (16.25,9), (16.5,9.5), (17,11), (17.5,10), (18,10), (18.4,9.5), (19,9)]]
records += [{ "dt": dt, "tt": tt, 'foo':'g' } for (dt, tt) in [(6,7), (6.4, 8), (7, 8), (7.5, 8.5), (8.5, 8.5), (10, 10), (11,10), (11.5, 9.8), (12, 9.8), (12.5,9.3), (13.5, 9.3), (14, 9.5), (14.5, 9.5), (14.8, 11), (15.25, 11), (15.75, 10.2), (16, 10.5), (16.5, 10.5), (17.5, 9), (18, 9), (18.3, 8.8), (19, 8.5)]]
df = pd.DataFrame.from_records(records)
fig, ax = plt.subplots(figsize=(16/7*2.5, 2.5))
g = sns.lineplot(data=df, x="dt", y="tt", hue='foo', ax=ax)
g.set(xlabel='Entry time', ylabel='Travel time [s]', xticks=[6, 9, 12, 15, 18])
g.set_xticklabels(['06:00', '09:00', '12:00', '15:00', '18:00'])
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.axvline(x=9.75)
ax.axvline(x=16.75, color=sns.color_palette()[1])
plt.tight_layout()
fig.savefig('../../paper/fig/merge.pdf')
